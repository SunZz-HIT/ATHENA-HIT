# %% [markdown]
# # 数据准备

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from keras.models import Model
from keras import regularizers
from sklearn.metrics import recall_score, confusion_matrix, roc_curve, auc, f1_score, precision_score
import numpy as np
import random

# 固定随机种子
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)
# 选择数据
data = pd.read_csv('data/all/train/4E7.csv')
valid_data = pd.read_csv('data/all/validation/4E7.csv')

time_series = data['Time'].values.reshape(-1, 1)

time_intervals = np.diff(data['Time'])

scaler = MinMaxScaler()
# normalized_intervals = scaler.fit_transform(time_intervals.reshape(-1, 1))
normalized_intervals = time_intervals.reshape(-1, 1)

# %%
def create_dataset(data, timesteps):
    X = []
    for i in range(len(data) - timesteps):
        X.append(data[i:i+timesteps])
    return np.array(X)

timesteps = 1
X_train = create_dataset(normalized_intervals, timesteps)

# %% [markdown]
# # LSTM模型

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(16, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(16, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(1))(L5)  # 修改输出维度为1
    model = Model(inputs=inputs, outputs=output)
    return model

# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1, 1)]            0
#
#  lstm (LSTM)                 (None, 1, 16)             1152
#
#  lstm_1 (LSTM)               (None, 16)                2112
#
#  repeat_vector (RepeatVector  (None, 1, 16)            0
#  )
#
#  lstm_2 (LSTM)               (None, 1, 16)             2112
#
#  lstm_3 (LSTM)               (None, 1, 16)             2112
#
#  time_distributed (TimeDistr  (None, 1, 1)             17
#  ibuted)
#
# =================================================================
# Total params: 7,505
# Trainable params: 7,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, X_train, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 352/352 [==============================] - 8s 6ms/step - loss: 0.0112 - val_loss: 1.1464e-04
# Epoch 2/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1188e-04 - val_loss: 2.0838e-04
# Epoch 3/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3480e-04 - val_loss: 9.9433e-05
# Epoch 4/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1392e-04 - val_loss: 1.0021e-04
# Epoch 5/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.5595e-04 - val_loss: 9.7665e-05
# Epoch 6/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2129e-04 - val_loss: 1.9020e-04
# Epoch 7/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3862e-04 - val_loss: 1.9682e-04
# Epoch 8/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3049e-04 - val_loss: 9.5630e-05
# Epoch 9/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1251e-04 - val_loss: 1.3293e-04
# Epoch 10/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4423e-04 - val_loss: 1.1279e-04
# Epoch 11/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2841e-04 - val_loss: 2.8485e-04
# Epoch 12/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3718e-04 - val_loss: 1.0673e-04
# Epoch 13/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2205e-04 - val_loss: 1.1305e-04
# Epoch 14/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3791e-04 - val_loss: 3.1071e-04
# Epoch 15/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2582e-04 - val_loss: 1.1739e-04
# Epoch 16/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4225e-04 - val_loss: 1.3811e-04
# Epoch 17/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4836e-04 - val_loss: 2.6929e-04
# Epoch 18/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3033e-04 - val_loss: 1.2762e-04
# Epoch 19/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3633e-04 - val_loss: 1.2474e-04
# Epoch 20/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1347e-04 - val_loss: 2.3448e-04
# Epoch 21/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3809e-04 - val_loss: 1.6886e-04
# Epoch 22/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1554e-04 - val_loss: 1.3850e-04
# Epoch 23/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3116e-04 - val_loss: 3.2160e-04
# Epoch 24/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2361e-04 - val_loss: 1.6646e-04
# Epoch 25/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3163e-04 - val_loss: 1.7339e-04
# Epoch 26/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1395e-04 - val_loss: 1.7552e-04
# Epoch 27/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4784e-04 - val_loss: 1.0246e-04
# Epoch 28/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1173e-04 - val_loss: 1.0541e-04
# Epoch 29/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2596e-04 - val_loss: 3.0933e-04
# Epoch 30/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1774e-04 - val_loss: 1.4860e-04
# Epoch 31/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1085e-04 - val_loss: 1.2201e-04
# Epoch 32/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.0830e-04 - val_loss: 2.4658e-04
# Epoch 33/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4434e-04 - val_loss: 1.1026e-04
# Epoch 34/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.4082e-04 - val_loss: 1.3886e-04
# Epoch 35/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2134e-04 - val_loss: 9.4567e-05
# Epoch 36/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2955e-04 - val_loss: 1.9179e-04
# Epoch 37/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1562e-04 - val_loss: 1.1166e-04
# Epoch 38/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3461e-04 - val_loss: 1.6009e-04
# Epoch 39/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.5781e-04 - val_loss: 4.0228e-04
# Epoch 40/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1243e-04 - val_loss: 1.1958e-04
# Epoch 41/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.1314e-04 - val_loss: 2.1681e-04
# Epoch 42/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3136e-04 - val_loss: 1.1371e-04
# Epoch 43/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2370e-04 - val_loss: 2.4579e-04
# Epoch 44/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.5454e-04 - val_loss: 9.6009e-05
# Epoch 45/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2582e-04 - val_loss: 1.2358e-04
# Epoch 46/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.3829e-04 - val_loss: 9.4312e-05
# Epoch 47/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2714e-04 - val_loss: 9.1886e-05
# Epoch 48/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2988e-04 - val_loss: 1.0609e-04
# Epoch 49/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2497e-04 - val_loss: 9.3023e-05
# Epoch 50/50
# 352/352 [==============================] - 1s 4ms/step - loss: 2.2631e-04 - val_loss: 1.8888e-04

# %%
predictions = model.predict(X_train)

# predict_y = predictions[:, 9, :]
predict_y = predictions[:, 0, :]
# Out:
# 391/391 [==============================] - 1s 2ms/step

# %%
train_error = np.abs(predict_y - X_train[:, 0, :])
train_error.shape
# Out:
# (12508, 1)

# %%
valid_intervals = valid_data['Time'].diff().dropna()
case_numbers = valid_data.index[1:].values
valid_intervals

np.diff(valid_data['Time']).mean()
# Out:
# 0.08571536544850498

# %% [markdown]
# # 异常识别

# %%
abnormals = []
is_attack_predicted = []
tmp_len = 0
for i in range(len(valid_intervals)):
    thr = predict_y.reshape(-1)[i] - 10 * np.mean(train_error)
    # thr = predict_y.reshape(-1)[i] - 2 * np.std(predict_y.reshape(-1))
    value = valid_intervals.values[i]
    if tmp_len != 0:
        value += tmp_len
        tmp_len = 0
    if value < thr:
        abnormals.append(case_numbers[i])
        is_attack_predicted.append(1)
        tmp_len = valid_intervals.values[i]
    else:
        is_attack_predicted.append(0)

print(len(abnormals))
# Out:
# 43

# %%
valid_data['is_attack'] = valid_data['Label'].apply(lambda x: 0 if x == 'Normal' else 1)

# %%
valid_data['is_attack'].sum()
# Out:
# 43

# %% [markdown]
# # 分类结果

# %%
is_attack_actual = valid_data['is_attack'].values[1:] # 对其处理数据时的索引差异

conf_matrix = confusion_matrix(is_attack_actual, is_attack_predicted)
print("混淆矩阵:")
print(conf_matrix)

# 计算 F1 分数
f1 = f1_score(is_attack_actual, is_attack_predicted)
print(f"F1 分数: {f1}")

# 计算召回率
recall = recall_score(is_attack_actual, is_attack_predicted)
print(f"召回率: {recall}")

accuracy = precision_score(is_attack_actual, is_attack_predicted)
print(f"准确率: {accuracy}")
# Out:
# 混淆矩阵:
# [[258   0]
#  [  0  43]]
# F1 分数: 1.0
# 召回率: 1.0
# 准确率: 1.0

# %%
is_attack = valid_data['is_attack'].values

# 绘制 Time 的模式
plt.figure(figsize=(12, 6))
plt.plot(valid_data['Time'].diff(), label='Time Series', color='blue', alpha=0.2)

# 标记出 is_attack = 1 的地方
attack_indices = np.where(is_attack == 1)[0]
plt.scatter(attack_indices, valid_data['Time'].diff()[attack_indices], color='red', label='Attack', s=10, alpha=0.2)

# 添加标题和标签
plt.title('4E7: Time Series with Attack Points')
plt.xlabel('Index')
plt.ylabel('Time')
plt.legend()

# 显示图形
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No Attack', 'Attack'], yticklabels=['No Attack', 'Attack'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# 绘制ROC曲线
fpr, tpr, _ = roc_curve(is_attack_actual, is_attack_predicted)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# 打印评估指标
print(f"Accuracy: {accuracy}")
print(f"Recall: {recall}")
print(f"Confusion Matrix:\n{conf_matrix}")
# Out:
# Accuracy: 1.0
# Recall: 1.0
# Confusion Matrix:
# [[258   0]
#  [  0  43]]
